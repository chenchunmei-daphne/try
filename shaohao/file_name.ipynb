# %%
import pandas as pd

# 读取Excel文件
excel_file = 'D:\chen\智能运维\新代点位历史数据.xls'

# 获取所有工作表名称
xls = pd.ExcelFile(excel_file)
sheet_names = xls.sheet_names

# 输出所有工作表名称
print("Excel文件中包含的工作表：")
for i, name in enumerate(sheet_names, 1):
    print(f"{i}. {name}")

# # 或者保存到文本文件
# with open('sheet_names.txt', 'w', encoding='utf-8') as f:
#     for name in sheet_names:
#         f.write(name + '\n')
# Out:
# Excel文件中包含的工作表：
# 1. old_WorkPiecesSet
# 2. ActSpindleSpeed
# 3. old_ActSpindleSpeed
# 4. WorkPiecesAct
# 5. RunningMode
# 6. old_RunningStatus
# 7. HandStatus
# 8. old_CycleTime
# 9. old_PosMachine_Axis2
# 10. old_PosAbsolute_Axis3
# 11. old_PosMachine_Axis1
# 12. old_PosAbsolute_Axis2
# 13. old_PosAbsolute_Axis1
# 14. old_PosMachine_Axis3
# 15. SpindleOverride
# 16. old_EmgStatus
# 17. PosMachine_Axis3
# 18. PosRelative_Axis1
# 19. ProgramName
# 20. PosMachine_Axis1
# 21. PosRelative_Axis2
# 22. PosMachine_Axis2
# 23. PosRelative_Axis3
# 24. old_PosRemain_Axis1
# 25. old_ActFeedSpeed
# 26. old_PosRemain_Axis3
# 27. ToolNo
# 28. old_PosRemain_Axis2
# 29. PosAbsolute_Axis2
# 30. PosAbsolute_Axis1
# 31. RunTime
# 32. PosAbsolute_Axis3
# 33. old_FeedOverride
# 34. old_RunTime
# 35. PosRemain_Axis1
# 36. PosRemain_Axis3
# 37. PosRemain_Axis2
# 38. CycleTime
# 39. RunningStatus
# 40. old_HandStatus
# 41. old_WorkPiecesAct
# 42. EmgStatus
# 43. ActFeedSpeed
# 44. FeedOverride
# 45. AlarmInformation
# 46. old_SpindleOverride
# 47. old_WorkProcessNum
# 48. old_ToolNo
# 49. WorkPiecesSet
# 50. WorkProcessNum
# 51. old_RunningMode
# 52. old_PosRelative_Axis2
# 53. old_PosRelative_Axis3
# 54. old_PosRelative_Axis1
