# %%
import torch
import torch.nn as nn

H = torch.tensor([[1, 2, 3], [4, 5, 6]], dtype=torch.float32)
H_est = torch.tensor([[0.8, 2.1, 3.1], [4.2, 5, 5.9]], dtype=torch.float32)

criterion = nn.MSELoss()
loss = criterion(H, H_est)
loss_ = torch.mean((H-H_est)**2)
print(loss, loss_)
# Out:
# tensor(0.0183) tensor(0.0183)

# %%
criterion(H_est, H)
# Out:
# tensor(0.0183)

# %%
H = torch.randint(0,10, (2,3,1,4))
H = H.float()
H
# Out:
# tensor([[[[2., 6., 7., 1.]],
#
#          [[5., 6., 4., 7.]],
#
#          [[7., 3., 8., 9.]]],
#
#
#         [[[3., 8., 7., 1.]],
#
#          [[7., 3., 6., 8.]],
#
#          [[5., 6., 2., 3.]]]])

# %%
norm_H = torch.norm(H.squeeze(-1), dim=-1)
norm_H.shape
# Out:
# torch.Size([2, 3, 1])

# %%
inner_product = torch.sum(H.conj() * H, dim=2).squeeze(-1)
inner_product.shape
# Out:
# torch.Size([2, 3, 4])

# %%
def complex_cosine_similarity2(h_true, h_est):
    """
    向量化版本的复数余弦相似度计算
    更高效，避免显式循环
    """
    
    
    # 计算每个向量的范数
    # norm_true shape: (batch, seq_len)
    norm_true = torch.norm(h_true.squeeze(-1), dim=-1)
    norm_est = torch.norm(h_est.squeeze(-1), dim=-1)
    
    # 计算复数内积: a^H * b
    # h_true.conj() 形状: (batch, seq_len, 256, 1)
    # 逐元素相乘后在第3个维度求和，得到形状: (batch, seq_len, 1)
    
    inner_product = torch.sum(h_true.conj() * h_est, dim=2).squeeze(-1)  # (batch, seq_len)
    
    # 取内积的模
    inner_product_abs = torch.abs(inner_product)  # (batch, seq_len)
    
    # 避免除以零
    epsilon = 1e-8
    cosine_sim = inner_product_abs / (norm_true * norm_est + epsilon)  # (batch, seq_len)
    
    # 在前两个维度求平均
    avg_cosine_sim = torch.mean(cosine_sim)
    
    return avg_cosine_sim.item()
